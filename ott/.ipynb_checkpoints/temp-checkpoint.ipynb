# %%
import pandas as pd

# %%
df0 = pd.read_csv('./test2.csv').drop('Unnamed: 0', axis=1)
df0
# Out:
#     reviewer                                             review
# 0         민초  우리시대를 추억하는 시리즈.\n좀 더 진중하고, 남편찾기 낚시질이 없었다면 수작이 ...
# 1      three               뒷심부족이 아쉬움..... 초반느낌 잘 이어갔으면 진짜 수작일텐데
# 2      송부귀영화  응칠의 후속인데 응칠의 아류같은 느낌만..\n고아라가 유연석에게 나의 20대를 아름...
# 3        박병욱  너무 많이 나정이 신랑 찾기 열풍뿐 후반엔 살짝 지루한느낌 그래도 응답하라 시리즈니...
# 4         21                                   나도 쓰레기오빠랑 결혼하고싶다
# 5        송경택                      그 시대를 살아보지 못한 이들도 응답하게 하는 매력.
# 6         유희  40대에게 향수와 위로를 \n30대에게 어린시절 느낌을\n20대에게 현재의 감정을\...
# 7        조아라                          내 사유재산이었던 유연석을 공공재로 만들다니.
# 8        장민수                                     16부작이였으면 완벽했겠지
# 9       청춘예찬                                      덕분에 행복했다 내군생활
# 10       기록용  젊은 날엔 젊음을 모르고\n사랑할 땐 사랑이 보이지 않았네\n하지만 이제 뒤돌아 보...
# 11     Jinny  응칠세대인데 응사에 더 환호했다. 뒷심부족이 아쉽긴 하지만 지나온 그 시간을 리얼하...
# 12       동욱쓰                              사랑보다는 우정이 너무 아름다워 보였다
# 13    hgee95  두고두고 보고 싶은 웰메이드 드라마.\n그 시절을 살았던 사람이 아님에도\n찡한 장...
# ...

# %%
df1 = pd.read_csv('./test_TM.csv').drop('Unnamed: 0', axis=1)
df1
# Out:
#           sa                                           sa_probs  score  \
# 0   Positive  {'negative': 0.002061634324491024, 'positive':...   4.78
# 1   Positive  {'negative': 0.16311436891555786, 'positive': ...   4.16
# 2   Negative  {'negative': 0.9982905983924866, 'positive': 0...   2.02
# 3   Negative  {'negative': 0.9640055894851685, 'positive': 0...   3.89
# 4   Negative  {'negative': 0.7094089984893799, 'positive': 0...   3.66
# 5   Positive  {'negative': 0.0020535599905997515, 'positive'...   4.87
# 6   Positive  {'negative': 0.0017199774738401175, 'positive'...   4.74
# 7   Negative  {'negative': 0.9948904514312744, 'positive': 0...   1.80
# 8   Negative  {'negative': 0.852035403251648, 'positive': 0....   3.85
# 9   Negative  {'negative': 0.8070231676101685, 'positive': 0...   4.69
# 10  Positive  {'negative': 0.0018977578729391098, 'positive'...   4.39
# 11  Positive  {'negative': 0.001917325658723712, 'positive':...   4.80
# ...

# %%
df2 = pd.read_csv('./test_preprocessed.csv').drop('Unnamed: 0', axis=1)
df2
# Out:
#       출연진    연기력   시나리오     연출   등장인물  score
# 0   23.35  38.82  84.73  29.65  79.95   4.78
# 1   49.10  77.89  73.36  75.86  76.97   4.16
# 2   88.70  49.12  74.93  65.49  92.45   2.02
# 3   49.84  37.84  65.30  38.72  72.85   3.89
# 4   49.19  45.26  57.63  60.29  87.31   3.66
# 5   27.85  70.34  51.24  42.23  69.46   4.87
# 6   37.19  14.69  10.96  22.88  85.90   4.74
# 7   21.36  74.30  62.24  69.91  60.63   1.80
# 8   47.87  50.16  69.23  69.64  76.89   3.85
# 9   64.81  78.07  67.00  55.05  83.59   4.69
# 10  47.74  58.18  36.65  63.76  92.41   4.39
# 11  32.81  61.80  38.97  49.87  76.78   4.80
# 12  47.92  45.25  31.84  66.99  92.74   4.64
# 13  42.14  33.41  40.48  24.83  80.19   4.99
# 14  72.31  28.71  55.41  57.48  91.68   4.96
# 15  45.06  46.10  73.64  74.85  85.37   3.44
# 16  51.74  30.01  52.56  41.52  91.32   3.84
# 17  41.74  38.62  60.07  42.04  72.04   1.75
# 18  56.44  45.16  36.76  79.01  85.23   4.36
# 19  17.98  22.53  52.60  51.11  63.81   1.25
# ...

# %%
df_total = pd.concat([df0, df1, df2], axis=1)
df_total
# Out:
#     reviewer                                             review        sa  \
# 0         민초  우리시대를 추억하는 시리즈.\n좀 더 진중하고, 남편찾기 낚시질이 없었다면 수작이 ...  Positive
# 1      three               뒷심부족이 아쉬움..... 초반느낌 잘 이어갔으면 진짜 수작일텐데  Positive
# 2      송부귀영화  응칠의 후속인데 응칠의 아류같은 느낌만..\n고아라가 유연석에게 나의 20대를 아름...  Negative
# 3        박병욱  너무 많이 나정이 신랑 찾기 열풍뿐 후반엔 살짝 지루한느낌 그래도 응답하라 시리즈니...  Negative
# 4         21                                   나도 쓰레기오빠랑 결혼하고싶다  Negative
# 5        송경택                      그 시대를 살아보지 못한 이들도 응답하게 하는 매력.  Positive
# 6         유희  40대에게 향수와 위로를 \n30대에게 어린시절 느낌을\n20대에게 현재의 감정을\...  Positive
# 7        조아라                          내 사유재산이었던 유연석을 공공재로 만들다니.  Negative
# 8        장민수                                     16부작이였으면 완벽했겠지  Negative
# 9       청춘예찬                                      덕분에 행복했다 내군생활  Negative
# 10       기록용  젊은 날엔 젊음을 모르고\n사랑할 땐 사랑이 보이지 않았네\n하지만 이제 뒤돌아 보...  Positive
# 11     Jinny  응칠세대인데 응사에 더 환호했다. 뒷심부족이 아쉽긴 하지만 지나온 그 시간을 리얼하...  Positive
# ...

# %%
df_total.to_csv('test_final.csv')
